# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv("Titanic/train.csv")
test = pd.read_csv("Titanic/test.csv")
submit = pd.read_csv("Titanic/gender_submission.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
data = train.append(test)
#data.reset_index(inplace=True, drop=True)
data
# Out:
#       Age        Cabin Embarked      Fare  \
# 0    22.0          NaN        S    7.2500
# 1    38.0          C85        C   71.2833
# 2    26.0          NaN        S    7.9250
# 3    35.0         C123        S   53.1000
# 4    35.0          NaN        S    8.0500
# 5     NaN          NaN        Q    8.4583
# 6    54.0          E46        S   51.8625
# 7     2.0          NaN        S   21.0750
# 8    27.0          NaN        S   11.1333
# 9    14.0          NaN        C   30.0708
# 10    4.0           G6        S   16.7000
# 11   58.0         C103        S   26.5500
# 12   20.0          NaN        S    8.0500
# 13   39.0          NaN        S   31.2750
# 14   14.0          NaN        S    7.8542
# 15   55.0          NaN        S   16.0000
# 16    2.0          NaN        Q   29.1250
# 17    NaN          NaN        S   13.0000
# 18   31.0          NaN        S   18.0000
# 19    NaN          NaN        C    7.2250
# 20   35.0          NaN        S   26.0000
# 21   34.0          D56        S   13.0000
# 22   15.0          NaN        Q    8.0292
# 23   28.0           A6        S   35.5000
# 24    8.0          NaN        S   21.0750
# 25   38.0          NaN        S   31.3875
# 26    NaN          NaN        C    7.2250
# 27   19.0  C23 C25 C27        S  263.0000
# 28    NaN          NaN        Q    7.8792
# 29    NaN          NaN        S    7.8958
# ..    ...          ...      ...       ...
# 388  21.0          NaN        Q    7.7500
# 389   6.0          NaN        S   21.0750
# 390  23.0          B24        S   93.5000
# 391  51.0          D28        S   39.4000
# 392  13.0          NaN        S   20.2500
# 393  47.0          NaN        S   10.5000
# 394  29.0          NaN        S   22.0250
# 395  18.0          C31        S   60.0000
# 396  24.0          NaN        Q    7.2500
# 397  48.0          B41        C   79.2000
# 398  22.0          NaN        S    7.7750
# 399  31.0          NaN        Q    7.7333
# 400  30.0           C7        S  164.8667
# 401  38.0          NaN        S   21.0000
# 402  22.0          NaN        C   59.4000
# 403  17.0          NaN        S   47.1000
# 404  43.0          D40        C   27.7208
# 405  20.0          D38        C   13.8625
# 406  23.0          NaN        S   10.5000
# 407  50.0          C80        C  211.5000
# 408   NaN          NaN        Q    7.7208
# 409   3.0          NaN        S   13.7750
# 410   NaN          NaN        Q    7.7500
# 411  37.0          C78        Q   90.0000
# 412  28.0          NaN        S    7.7750
# 413   NaN          NaN        S    8.0500
# 414  39.0         C105        C  108.9000
# 415  38.5          NaN        S    7.2500
# 416   NaN          NaN        S    8.0500
# 417   NaN          NaN        C   22.3583
#
#                                                   Name  Parch  PassengerId  \
# 0                              Braund, Mr. Owen Harris      0            1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                               Heikkinen, Miss. Laina      0            3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                             Allen, Mr. William Henry      0            5
# 5                                     Moran, Mr. James      0            6
# 6                              McCarthy, Mr. Timothy J      0            7
# 7                       Palsson, Master. Gosta Leonard      1            8
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                  Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                     Sandstrom, Miss. Marguerite Rut      1           11
# 11                            Bonnell, Miss. Elizabeth      0           12
# 12                      Saundercock, Mr. William Henry      0           13
# 13                         Andersson, Mr. Anders Johan      5           14
# 14                Vestrom, Miss. Hulda Amanda Adolfina      0           15
# 15                    Hewlett, Mrs. (Mary D Kingcome)       0           16
# 16                                Rice, Master. Eugene      1           17
# 17                        Williams, Mr. Charles Eugene      0           18
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 19                             Masselmani, Mrs. Fatima      0           20
# 20                                Fynney, Mr. Joseph J      0           21
# 21                               Beesley, Mr. Lawrence      0           22
# 22                         McGowan, Miss. Anna "Annie"      0           23
# 23                        Sloper, Mr. William Thompson      0           24
# 24                       Palsson, Miss. Torborg Danira      1           25
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 26                             Emir, Mr. Farred Chehab      0           27
# 27                      Fortune, Mr. Charles Alexander      2           28
# 28                       O'Dwyer, Miss. Ellen "Nellie"      0           29
# 29                                 Todoroff, Mr. Lalio      0           30
# ..                                                 ...    ...          ...
# 388                               Canavan, Mr. Patrick      0         1280
# 389                        Palsson, Master. Paul Folke      1         1281
# 390                         Payne, Mr. Vivian Ponsonby      0         1282
# 391     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 392                      Abbott, Master. Eugene Joseph      2         1284
# 393                               Gilbert, Mr. William      0         1285
# 394                           Kink-Heilmann, Mr. Anton      1         1286
# 395     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 396                               Colbert, Mr. Patrick      0         1288
# 397  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 398                     Larsson-Rondberg, Mr. Edvard A      0         1290
# 399                           Conlon, Mr. Thomas Henry      0         1291
# 400                            Bonnell, Miss. Caroline      0         1292
# 401                                    Gale, Mr. Harry      0         1293
# 402                     Gibson, Miss. Dorothy Winifred      1         1294
# 403                             Carrau, Mr. Jose Pedro      0         1295
# 404                       Frauenthal, Mr. Isaac Gerald      0         1296
# 405       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297
# 406                          Ware, Mr. William Jeffery      0         1298
# 407                         Widener, Mr. George Dunton      1         1299
# 408                    Riordan, Miss. Johanna Hannah""      0         1300
# 409                          Peacock, Miss. Treasteall      1         1301
# 410                             Naughton, Miss. Hannah      0         1302
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 412                     Henriksson, Miss. Jenny Lovisa      0         1304
# 413                                 Spector, Mr. Woolf      0         1305
# 414                       Oliva y Ocana, Dona. Fermina      0         1306
# 415                       Saether, Mr. Simon Sivertsen      0         1307
# 416                                Ware, Mr. Frederick      0         1308
# 417                           Peter, Master. Michael J      1         1309
#
#      Pclass     Sex  SibSp  Survived              Ticket
# 0         3    male      1       0.0           A/5 21171
# 1         1  female      1       1.0            PC 17599
# 2         3  female      0       1.0    STON/O2. 3101282
# 3         1  female      1       1.0              113803
# 4         3    male      0       0.0              373450
# 5         3    male      0       0.0              330877
# 6         1    male      0       0.0               17463
# 7         3    male      3       0.0              349909
# 8         3  female      0       1.0              347742
# 9         2  female      1       1.0              237736
# 10        3  female      1       1.0             PP 9549
# 11        1  female      0       1.0              113783
# 12        3    male      0       0.0           A/5. 2151
# 13        3    male      1       0.0              347082
# 14        3  female      0       0.0              350406
# 15        2  female      0       1.0              248706
# 16        3    male      4       0.0              382652
# 17        2    male      0       1.0              244373
# 18        3  female      1       0.0              345763
# 19        3  female      0       1.0                2649
# 20        2    male      0       0.0              239865
# 21        2    male      0       1.0              248698
# 22        3  female      0       1.0              330923
# 23        1    male      0       1.0              113788
# 24        3  female      3       0.0              349909
# 25        3  female      1       1.0              347077
# 26        3    male      0       0.0                2631
# 27        1    male      3       0.0               19950
# 28        3  female      0       1.0              330959
# 29        3    male      0       0.0              349216
# ..      ...     ...    ...       ...                 ...
# 388       3    male      0       NaN              364858
# 389       3    male      3       NaN              349909
# 390       1    male      0       NaN               12749
# 391       1  female      0       NaN            PC 17592
# 392       3    male      0       NaN           C.A. 2673
# 393       2    male      0       NaN          C.A. 30769
# 394       3    male      3       NaN              315153
# 395       1  female      1       NaN               13695
# 396       3    male      0       NaN              371109
# 397       1  female      1       NaN               13567
# 398       3    male      0       NaN              347065
# 399       3    male      0       NaN               21332
# 400       1  female      0       NaN               36928
# 401       2    male      1       NaN               28664
# 402       1  female      0       NaN              112378
# 403       1    male      0       NaN              113059
# 404       1    male      1       NaN               17765
# 405       2    male      0       NaN       SC/PARIS 2166
# 406       2    male      1       NaN               28666
# 407       1    male      1       NaN              113503
# 408       3  female      0       NaN              334915
# 409       3  female      1       NaN  SOTON/O.Q. 3101315
# 410       3  female      0       NaN              365237
# 411       1  female      1       NaN               19928
# 412       3  female      0       NaN              347086
# 413       3    male      0       NaN           A.5. 3236
# 414       1  female      0       NaN            PC 17758
# 415       3    male      0       NaN  SOTON/O.Q. 3101262
# 416       3    male      0       NaN              359309
# 417       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %%
data.reset_index(inplace=True, drop=True)
data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# 21    34.0          D56        S   13.0000
# 22    15.0          NaN        Q    8.0292
# 23    28.0           A6        S   35.5000
# 24     8.0          NaN        S   21.0750
# 25    38.0          NaN        S   31.3875
# 26     NaN          NaN        C    7.2250
# 27    19.0  C23 C25 C27        S  263.0000
# 28     NaN          NaN        Q    7.8792
# 29     NaN          NaN        S    7.8958
# ...    ...          ...      ...       ...
# 1279  21.0          NaN        Q    7.7500
# 1280   6.0          NaN        S   21.0750
# 1281  23.0          B24        S   93.5000
# 1282  51.0          D28        S   39.4000
# 1283  13.0          NaN        S   20.2500
# 1284  47.0          NaN        S   10.5000
# 1285  29.0          NaN        S   22.0250
# 1286  18.0          C31        S   60.0000
# 1287  24.0          NaN        Q    7.2500
# 1288  48.0          B41        C   79.2000
# 1289  22.0          NaN        S    7.7750
# 1290  31.0          NaN        Q    7.7333
# 1291  30.0           C7        S  164.8667
# 1292  38.0          NaN        S   21.0000
# 1293  22.0          NaN        C   59.4000
# 1294  17.0          NaN        S   47.1000
# 1295  43.0          D40        C   27.7208
# 1296  20.0          D38        C   13.8625
# 1297  23.0          NaN        S   10.5000
# 1298  50.0          C80        C  211.5000
# 1299   NaN          NaN        Q    7.7208
# 1300   3.0          NaN        S   13.7750
# 1301   NaN          NaN        Q    7.7500
# 1302  37.0          C78        Q   90.0000
# 1303  28.0          NaN        S    7.7750
# 1304   NaN          NaN        S    8.0500
# 1305  39.0         C105        C  108.9000
# 1306  38.5          NaN        S    7.2500
# 1307   NaN          NaN        S    8.0500
# 1308   NaN          NaN        C   22.3583
#
#                                                    Name  Parch  PassengerId  \
# 0                               Braund, Mr. Owen Harris      0            1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                                Heikkinen, Miss. Laina      0            3
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                              Allen, Mr. William Henry      0            5
# 5                                      Moran, Mr. James      0            6
# 6                               McCarthy, Mr. Timothy J      0            7
# 7                        Palsson, Master. Gosta Leonard      1            8
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)      2            9
# 9                   Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 10                      Sandstrom, Miss. Marguerite Rut      1           11
# 11                             Bonnell, Miss. Elizabeth      0           12
# 12                       Saundercock, Mr. William Henry      0           13
# 13                          Andersson, Mr. Anders Johan      5           14
# 14                 Vestrom, Miss. Hulda Amanda Adolfina      0           15
# 15                     Hewlett, Mrs. (Mary D Kingcome)       0           16
# 16                                 Rice, Master. Eugene      1           17
# 17                         Williams, Mr. Charles Eugene      0           18
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...      0           19
# 19                              Masselmani, Mrs. Fatima      0           20
# 20                                 Fynney, Mr. Joseph J      0           21
# 21                                Beesley, Mr. Lawrence      0           22
# 22                          McGowan, Miss. Anna "Annie"      0           23
# 23                         Sloper, Mr. William Thompson      0           24
# 24                        Palsson, Miss. Torborg Danira      1           25
# 25    Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...      5           26
# 26                              Emir, Mr. Farred Chehab      0           27
# 27                       Fortune, Mr. Charles Alexander      2           28
# 28                        O'Dwyer, Miss. Ellen "Nellie"      0           29
# 29                                  Todoroff, Mr. Lalio      0           30
# ...                                                 ...    ...          ...
# 1279                               Canavan, Mr. Patrick      0         1280
# 1280                        Palsson, Master. Paul Folke      1         1281
# 1281                         Payne, Mr. Vivian Ponsonby      0         1282
# 1282     Lines, Mrs. Ernest H (Elizabeth Lindsey James)      1         1283
# 1283                      Abbott, Master. Eugene Joseph      2         1284
# 1284                               Gilbert, Mr. William      0         1285
# 1285                           Kink-Heilmann, Mr. Anton      1         1286
# 1286     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)      0         1287
# 1287                               Colbert, Mr. Patrick      0         1288
# 1288  Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...      1         1289
# 1289                     Larsson-Rondberg, Mr. Edvard A      0         1290
# 1290                           Conlon, Mr. Thomas Henry      0         1291
# 1291                            Bonnell, Miss. Caroline      0         1292
# 1292                                    Gale, Mr. Harry      0         1293
# 1293                     Gibson, Miss. Dorothy Winifred      1         1294
# 1294                             Carrau, Mr. Jose Pedro      0         1295
# 1295                       Frauenthal, Mr. Isaac Gerald      0         1296
# 1296       Nourney, Mr. Alfred (Baron von Drachstedt")"      0         1297
# 1297                          Ware, Mr. William Jeffery      0         1298
# 1298                         Widener, Mr. George Dunton      1         1299
# 1299                    Riordan, Miss. Johanna Hannah""      0         1300
# 1300                          Peacock, Miss. Treasteall      1         1301
# 1301                             Naughton, Miss. Hannah      0         1302
# 1302    Minahan, Mrs. William Edward (Lillian E Thorpe)      0         1303
# 1303                     Henriksson, Miss. Jenny Lovisa      0         1304
# 1304                                 Spector, Mr. Woolf      0         1305
# 1305                       Oliva y Ocana, Dona. Fermina      0         1306
# 1306                       Saether, Mr. Simon Sivertsen      0         1307
# 1307                                Ware, Mr. Frederick      0         1308
# 1308                           Peter, Master. Michael J      1         1309
#
#       Pclass     Sex  SibSp  Survived              Ticket
# 0          3    male      1       0.0           A/5 21171
# 1          1  female      1       1.0            PC 17599
# 2          3  female      0       1.0    STON/O2. 3101282
# 3          1  female      1       1.0              113803
# 4          3    male      0       0.0              373450
# 5          3    male      0       0.0              330877
# 6          1    male      0       0.0               17463
# 7          3    male      3       0.0              349909
# 8          3  female      0       1.0              347742
# 9          2  female      1       1.0              237736
# 10         3  female      1       1.0             PP 9549
# 11         1  female      0       1.0              113783
# 12         3    male      0       0.0           A/5. 2151
# 13         3    male      1       0.0              347082
# 14         3  female      0       0.0              350406
# 15         2  female      0       1.0              248706
# 16         3    male      4       0.0              382652
# 17         2    male      0       1.0              244373
# 18         3  female      1       0.0              345763
# 19         3  female      0       1.0                2649
# 20         2    male      0       0.0              239865
# 21         2    male      0       1.0              248698
# 22         3  female      0       1.0              330923
# 23         1    male      0       1.0              113788
# 24         3  female      3       0.0              349909
# 25         3  female      1       1.0              347077
# 26         3    male      0       0.0                2631
# 27         1    male      3       0.0               19950
# 28         3  female      0       1.0              330959
# 29         3    male      0       0.0              349216
# ...      ...     ...    ...       ...                 ...
# 1279       3    male      0       NaN              364858
# 1280       3    male      3       NaN              349909
# 1281       1    male      0       NaN               12749
# 1282       1  female      0       NaN            PC 17592
# 1283       3    male      0       NaN           C.A. 2673
# 1284       2    male      0       NaN          C.A. 30769
# 1285       3    male      3       NaN              315153
# 1286       1  female      1       NaN               13695
# 1287       3    male      0       NaN              371109
# 1288       1  female      1       NaN               13567
# 1289       3    male      0       NaN              347065
# 1290       3    male      0       NaN               21332
# 1291       1  female      0       NaN               36928
# 1292       2    male      1       NaN               28664
# 1293       1  female      0       NaN              112378
# 1294       1    male      0       NaN              113059
# 1295       1    male      1       NaN               17765
# 1296       2    male      0       NaN       SC/PARIS 2166
# 1297       2    male      1       NaN               28666
# 1298       1    male      1       NaN              113503
# 1299       3  female      0       NaN              334915
# 1300       3  female      1       NaN  SOTON/O.Q. 3101315
# 1301       3  female      0       NaN              365237
# 1302       1  female      1       NaN               19928
# 1303       3  female      0       NaN              347086
# 1304       3    male      0       NaN           A.5. 3236
# 1305       1  female      0       NaN            PC 17758
# 1306       3    male      0       NaN  SOTON/O.Q. 3101262
# 1307       3    male      0       NaN              359309
# 1308       3    male      1       NaN                2668
#
# [1309 rows x 12 columns]

# %%
sns.countplot(data['Survived'])

# %%
sns.countplot(data['Pclass'], hue=data['Survived'])

# %%
sns.countplot(data['Sex'], hue=data['Survived'])

# %%
sns.countplot(data['Embarked'], hue=data['Survived'])

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Fare', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
g = sns.FacetGrid(data, col='Embarked')
g.map(sns.distplot, 'Fare', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
g = sns.FacetGrid(data, col='Embarked')
g.map(sns.distplot, 'Survived', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Age', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Parch', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'SibSp', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
data['Family_Size'] = data['Parch'] + data['SibSp']
g = sns.FacetGrid(data, col='Survived')
g.map(sns.distplot, 'Family_Size', kde=False)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# /home/rozen/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# # Feature Engineering

# %%
data['Title1'] = data['Name'].str.split(", ", expand=True)[1]
data['Name'].str.split(", ", expand=True).head(3)
# Out:
#            0                                           1
# 0     Braund                             Mr. Owen Harris
# 1    Cumings  Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                 Miss. Laina

# %%
data['Title1'].head(3)
# Out:
# 0                               Mr. Owen Harris
# 1    Mrs. John Bradley (Florence Briggs Thayer)
# 2                                   Miss. Laina
# Name: Title1, dtype: object

# %%
data['Title1'] = data['Title1'].str.split(".", expand=True)[0]
data['Title1'].head(3)
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# Name: Title1, dtype: object

# %%
data['Title1'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'the Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %% [markdown]
# ### Analysis

# %%
pd.crosstab(data['Title1'], data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col0 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col1 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col2 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col3 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col4 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col5 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col6 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col7 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col8 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col9 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col10 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col11 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col12 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col13 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col14 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col15 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col16 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col17 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col0 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col1 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col2 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col3 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col4 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col5 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col6 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col7 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col8 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col9 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col10 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col11 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col12 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col13 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col14 {
#             background-color:  #ffff66;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col15 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col16 {
#             background-color:  #008066;
#         }    #T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col17 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_4a465bb6_3858_11e9_ac16_309c23b7caee" >
# <thead>    <tr>
#         <th class="index_name level0" >Title1</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Don</th>
#         <th class="col_heading level0 col3" >Dona</th>
#         <th class="col_heading level0 col4" >Dr</th>
#         <th class="col_heading level0 col5" >Jonkheer</th>
#         <th class="col_heading level0 col6" >Lady</th>
#         <th class="col_heading level0 col7" >Major</th>
#         <th class="col_heading level0 col8" >Master</th>
#         <th class="col_heading level0 col9" >Miss</th>
#         <th class="col_heading level0 col10" >Mlle</th>
#         <th class="col_heading level0 col11" >Mme</th>
#         <th class="col_heading level0 col12" >Mr</th>
#         <th class="col_heading level0 col13" >Mrs</th>
#         <th class="col_heading level0 col14" >Ms</th>
#         <th class="col_heading level0 col15" >Rev</th>
#         <th class="col_heading level0 col16" >Sir</th>
#         <th class="col_heading level0 col17" >the Countess</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4a465bb6_3858_11e9_ac16_309c23b7caeelevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col0" class="data row0 col0" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col1" class="data row0 col1" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col2" class="data row0 col2" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col3" class="data row0 col3" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col4" class="data row0 col4" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col5" class="data row0 col5" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col6" class="data row0 col6" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col7" class="data row0 col7" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col8" class="data row0 col8" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col9" class="data row0 col9" >260</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col10" class="data row0 col10" >2</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col11" class="data row0 col11" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col12" class="data row0 col12" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col13" class="data row0 col13" >197</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col14" class="data row0 col14" >2</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col15" class="data row0 col15" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col16" class="data row0 col16" >0</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow0_col17" class="data row0 col17" >1</td>
#     </tr>    <tr>
#         <th id="T_4a465bb6_3858_11e9_ac16_309c23b7caeelevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col0" class="data row1 col0" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col1" class="data row1 col1" >4</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309c23b7caeerow1_col2" class="data row1 col2" >1</td>
#         <td id="T_4a465bb6_3858_11e9_ac16_309

# %%
pd.crosstab(data['Title1'], data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col0 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col1 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col2 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col3 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col4 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col5 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col6 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col7 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col8 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col9 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col10 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col11 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col12 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col13 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col14 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col15 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col16 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col0 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col1 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col2 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col3 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col4 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col5 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col6 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col7 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col8 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col9 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col10 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col11 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col12 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col13 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col14 {
#             background-color:  #ffff66;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col15 {
#             background-color:  #008066;
#         }    #T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col16 {
#             background-color:  #008066;
#         }</style>
# <table id="T_4a5942f8_3858_11e9_ac16_309c23b7caee" >
# <thead>    <tr>
#         <th class="index_name level0" >Title1</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Don</th>
#         <th class="col_heading level0 col3" >Dr</th>
#         <th class="col_heading level0 col4" >Jonkheer</th>
#         <th class="col_heading level0 col5" >Lady</th>
#         <th class="col_heading level0 col6" >Major</th>
#         <th class="col_heading level0 col7" >Master</th>
#         <th class="col_heading level0 col8" >Miss</th>
#         <th class="col_heading level0 col9" >Mlle</th>
#         <th class="col_heading level0 col10" >Mme</th>
#         <th class="col_heading level0 col11" >Mr</th>
#         <th class="col_heading level0 col12" >Mrs</th>
#         <th class="col_heading level0 col13" >Ms</th>
#         <th class="col_heading level0 col14" >Rev</th>
#         <th class="col_heading level0 col15" >Sir</th>
#         <th class="col_heading level0 col16" >the Countess</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_4a5942f8_3858_11e9_ac16_309c23b7caeelevel0_row0" class="row_heading level0 row0" >0.0</th>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col0" class="data row0 col0" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col1" class="data row0 col1" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col2" class="data row0 col2" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col3" class="data row0 col3" >4</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col4" class="data row0 col4" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col5" class="data row0 col5" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col6" class="data row0 col6" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col7" class="data row0 col7" >17</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col8" class="data row0 col8" >55</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col9" class="data row0 col9" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col10" class="data row0 col10" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col11" class="data row0 col11" >436</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col12" class="data row0 col12" >26</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col13" class="data row0 col13" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col14" class="data row0 col14" >6</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col15" class="data row0 col15" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow0_col16" class="data row0 col16" >0</td>
#     </tr>    <tr>
#         <th id="T_4a5942f8_3858_11e9_ac16_309c23b7caeelevel0_row1" class="row_heading level0 row1" >1.0</th>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col0" class="data row1 col0" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col1" class="data row1 col1" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col2" class="data row1 col2" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col3" class="data row1 col3" >3</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col4" class="data row1 col4" >0</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col5" class="data row1 col5" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeerow1_col6" class="data row1 col6" >1</td>
#         <td id="T_4a5942f8_3858_11e9_ac16_309c23b7caeer

# %%
pd.crosstab(data['Title1'], [data['Sex'], data['Survived']]).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col0 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col1 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col2 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col3 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col4 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col5 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col6 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col7 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col8 {
#             background-color:  #91c866;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col9 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col10 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col11 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col12 {
#             background-color:  #bcde66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col13 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col14 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col15 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow0_col16 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col0 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col1 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col2 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col3 {
#             background-color:  #bfdf66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col4 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col5 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col6 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col7 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col8 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col9 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col10 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col11 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col12 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col13 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col14 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col15 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow1_col16 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col0 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col1 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col2 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col3 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col4 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col5 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col6 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col7 {
#             background-color:  #42a066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col8 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col9 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col10 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col11 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col12 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col13 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col14 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col15 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow2_col16 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col0 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col1 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col2 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col3 {
#             background-color:  #7fbf66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col4 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col5 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col6 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col7 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col8 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col9 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col10 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col11 {
#             background-color:  #d0e866;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col12 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col13 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col14 {
#             background-color:  #ffff66;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col15 {
#             background-color:  #008066;
#         }    #T_4b8cf4da_3858_11e9_ac16_309c23b7caeerow3_col16 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_4b8cf4da_3858_11e9_ac16_309c23b7caee" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="index_name level0" >Title1</th>
#         <th class="col_heading level0 col0" >Capt</th>
#         <th class="col_heading level0 col1" >Col</th>
#         <th class="col_heading level0 col2" >Don</th>
#         <th class="col_heading level0 col3" >Dr</th>
#         <th class="col_heading level0 col4" >Jonkheer</th>
#         <th class="col_heading level0 col5" >Lady</th>
#         <th class="col_heading level0 col6" >Major</th>
#         <th class="col_heading level0 col7" >Master</th>
#         <th class="col_heading level0 col8" >Miss</th>
#         <th class="col_heading level0 col9" >Mlle</th>
#         <th class="col_heading level0 col10" >Mme</th>
#         <th class="col_heading level0 col11" >Mr</th>
#         <th class="col_heading l

# %%
data.groupby(['Title1'])['Age'].mean()
# Out:
# Title1
# Capt            70.000000
# Col             54.000000
# Don             40.000000
# Dona            39.000000
# Dr              43.571429
# Jonkheer        38.000000
# Lady            48.000000
# Major           48.500000
# Master           5.482642
# Miss            21.774238
# Mlle            24.000000
# Mme             24.000000
# Mr              32.252151
# Mrs             36.994118
# Ms              28.000000
# Rev             41.250000
# Sir             49.000000
# the Countess    33.000000
# Name: Age, dtype: float64

# %% [markdown]
# Look like is called by __Master__ is children is most survivor

# %%
data.groupby(['Title1','Pclass'])['Age'].mean()
# Out:
# Title1        Pclass
# Capt          1         70.000000
# Col           1         54.000000
# Don           1         40.000000
# Dona          1         39.000000
# Dr            1         45.600000
#               2         38.500000
# Jonkheer      1         38.000000
# Lady          1         48.000000
# Major         1         48.500000
# Master        1          6.984000
#               2          2.757273
#               3          6.090000
# Miss          1         30.338983
#               2         20.717083
#               3         17.360874
# Mlle          1         24.000000
# Mme           1         24.000000
# Mr            1         41.450758
#               2         32.346715
#               3         28.318910
# Mrs           1         43.208955
#               2         33.518519
#               3         32.326531
# Ms            2         28.000000
#               3               NaN
# Rev           2         41.250000
# Sir           1         49.000000
# the Countess  1         33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title1', 'Sex'])['Age'].mean()
# Out:
# Title1        Sex
# Capt          male      70.000000
# Col           male      54.000000
# Don           male      40.000000
# Dona          female    39.000000
# Dr            female    49.000000
#               male      42.666667
# Jonkheer      male      38.000000
# Lady          female    48.000000
# Major         male      48.500000
# Master        male       5.482642
# Miss          female    21.774238
# Mlle          female    24.000000
# Mme           female    24.000000
# Mr            male      32.252151
# Mrs           female    36.994118
# Ms            female    28.000000
# Rev           male      41.250000
# Sir           male      49.000000
# the Countess  female    33.000000
# Name: Age, dtype: float64

# %%
data['Title2'] = data['Title1'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','the Countess','Jonkheer','Col','Rev','Capt','Sir','Don','Dona'],
         ['Miss','Miss','Miss','Dr','Mr','Mrs','Mrs','Mr','Mr','Mr','Mr','Mr','Mr','Mrs'])
data['Title2'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Dr'], dtype=object)

# %%
data.groupby('Title2')['Age'].mean()
# Out:
# Title2
# Dr        43.571429
# Master     5.482642
# Miss      21.834533
# Mr        32.685309
# Mrs       37.046243
# Name: Age, dtype: float64

# %%
data.groupby(['Title2','Pclass'])['Age'].mean()
# Out:
# Title2  Pclass
# Dr      1         45.600000
#         2         38.500000
# Master  1          6.984000
#         2          2.757273
#         3          6.090000
# Miss    1         30.032258
#         2         20.865714
#         3         17.360874
# Mr      1         42.123239
#         2         32.837931
#         3         28.318910
# Mrs     1         43.071429
#         2         33.518519
#         3         32.326531
# Name: Age, dtype: float64

# %% [markdown]
# Look like Dr. are rich

# %%
pd.crosstab(data['Title2'], data['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col0 {
#             background-color:  #ffff66;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col1 {
#             background-color:  #ffff66;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col2 {
#             background-color:  #008066;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col3 {
#             background-color:  #ffff66;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col4 {
#             background-color:  #008066;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col0 {
#             background-color:  #008066;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col1 {
#             background-color:  #008066;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col2 {
#             background-color:  #ffff66;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col3 {
#             background-color:  #008066;
#         }    #T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col4 {
#             background-color:  #ffff66;
#         }</style>
# <table id="T_550e00c6_3858_11e9_ac16_309c23b7caee" >
# <thead>    <tr>
#         <th class="index_name level0" >Title2</th>
#         <th class="col_heading level0 col0" >Dr</th>
#         <th class="col_heading level0 col1" >Master</th>
#         <th class="col_heading level0 col2" >Miss</th>
#         <th class="col_heading level0 col3" >Mr</th>
#         <th class="col_heading level0 col4" >Mrs</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_550e00c6_3858_11e9_ac16_309c23b7caeelevel0_row0" class="row_heading level0 row0" >female</th>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col0" class="data row0 col0" >1</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col1" class="data row0 col1" >0</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col2" class="data row0 col2" >265</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col3" class="data row0 col3" >0</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow0_col4" class="data row0 col4" >200</td>
#     </tr>    <tr>
#         <th id="T_550e00c6_3858_11e9_ac16_309c23b7caeelevel0_row1" class="row_heading level0 row1" >male</th>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col0" class="data row1 col0" >7</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col1" class="data row1 col1" >61</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col2" class="data row1 col2" >0</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col3" class="data row1 col3" >775</td>
#         <td id="T_550e00c6_3858_11e9_ac16_309c23b7caeerow1_col4" class="data row1 col4" >0</td>
#     </tr></tbody>
# </table>

# %%
pd.crosstab(data['Title2'], data['Survived']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col0 {
#             background-color:  #008066;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col1 {
#             background-color:  #ffff66;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col2 {
#             background-color:  #ffff66;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col3 {
#             background-color:  #008066;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col4 {
#             background-color:  #ffff66;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col0 {
#             background-color:  #ffff66;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col1 {
#             background-color:  #008066;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col2 {
#             background-color:  #008066;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col3 {
#             background-color:  #ffff66;
#         }    #T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col4 {
#             background-color:  #008066;
#         }</style>
# <table id="T_5548e7fe_3858_11e9_ac16_309c23b7caee" >
# <thead>    <tr>
#         <th class="index_name level0" >Title2</th>
#         <th class="col_heading level0 col0" >Dr</th>
#         <th class="col_heading level0 col1" >Master</th>
#         <th class="col_heading level0 col2" >Miss</th>
#         <th class="col_heading level0 col3" >Mr</th>
#         <th class="col_heading level0 col4" >Mrs</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Survived</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5548e7fe_3858_11e9_ac16_309c23b7caeelevel0_row0" class="row_heading level0 row0" >0.0</th>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col0" class="data row0 col0" >4</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col1" class="data row0 col1" >17</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col2" class="data row0 col2" >55</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col3" class="data row0 col3" >447</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow0_col4" class="data row0 col4" >26</td>
#     </tr>    <tr>
#         <th id="T_5548e7fe_3858_11e9_ac16_309c23b7caeelevel0_row1" class="row_heading level0 row1" >1.0</th>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col0" class="data row1 col0" >3</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col1" class="data row1 col1" >23</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col2" class="data row1 col2" >131</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col3" class="data row1 col3" >84</td>
#         <td id="T_5548e7fe_3858_11e9_ac16_309c23b7caeerow1_col4" class="data row1 col4" >101</td>
#     </tr></tbody>
# </table>

# %%
list(data.groupby(['Title2','Pclass'])['Age'].mean().iteritems())[:3]
# Out:
# [(('Dr', 1), 45.6), (('Dr', 2), 38.5), (('Master', 1), 6.984)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 15 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# Title1         1309 non-null object
# Title2         1309 non-null object
# dtypes: float64(3), int64(5), object(7)
# memory usage: 153.5+ KB

# %%
data['Ticket_info'] = data['Ticket'].apply(lambda x : x.replace(".","").replace("/","").strip().split(' ')[0] if not x.isdigit() else 'X')

# %%
data['Ticket_info'].unique()
# Out:
# array(['A5', 'PC', 'STONO2', 'X', 'PP', 'CA', 'SCParis', 'SCA4', 'A4',
#        'SP', 'SOC', 'WC', 'SOTONOQ', 'WEP', 'STONO', 'C', 'SCPARIS',
#        'SOP', 'Fa', 'LINE', 'FCC', 'SWPP', 'SCOW', 'PPP', 'SC', 'SCAH',
#        'AS', 'SOPP', 'FC', 'SOTONO2', 'CASOTON', 'SCA3', 'STONOQ', 'AQ4',
#        'A', 'LP', 'AQ3'], dtype=object)

# %%
sector = data.groupby(['Ticket_info'])['Survived']
sector.size()
# Out:
# Ticket_info
# A            1
# A4          10
# A5          28
# AQ3          1
# AQ4          1
# AS           1
# C            8
# CA          68
# CASOTON      1
# FC           3
# FCC          9
# Fa           1
# LINE         4
# LP           1
# PC          92
# PP           4
# PPP          2
# SC           2
# SCA3         1
# SCA4         2
# SCAH         5
# SCOW         1
# SCPARIS     14
# SCParis      5
# SOC          8
# SOP          1
# SOPP         7
# SOTONO2      3
# SOTONOQ     24
# SP           1
# STONO       14
# STONO2       7
# STONOQ       1
# SWPP         2
# WC          15
# WEP          4
# X          957
# Name: Survived, dtype: int64

# %%
sector.mean()
# Out:
# Ticket_info
# A               NaN
# A4         0.000000
# A5         0.095238
# AQ3             NaN
# AQ4             NaN
# AS         0.000000
# C          0.400000
# CA         0.341463
# CASOTON    0.000000
# FC         0.000000
# FCC        0.800000
# Fa         0.000000
# LINE       0.250000
# LP              NaN
# PC         0.650000
# PP         0.666667
# PPP        0.500000
# SC         1.000000
# SCA3            NaN
# SCA4       0.000000
# SCAH       0.666667
# SCOW       0.000000
# SCPARIS    0.428571
# SCParis    0.500000
# SOC        0.166667
# SOP        0.000000
# SOPP       0.000000
# SOTONO2    0.000000
# SOTONOQ    0.133333
# SP         0.000000
# STONO      0.416667
# STONO2     0.500000
# STONOQ          NaN
# SWPP       1.000000
# WC         0.100000
# WEP        0.333333
# X          0.384266
# Name: Survived, dtype: float64

# %%
sns.countplot(data['Ticket_info'], hue=data['Survived'])

# %% [markdown]
# ## Missing Value-embarked、Fare、Age

# %%
data['Embarked'] = data['Embarked'].fillna('S')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1309 non-null object
# Fare           1308 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# Title1         1309 non-null object
# Title2         1309 non-null object
# Ticket_info    1309 non-null object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.7+ KB

# %%
data['Fare'] = data['Fare'].fillna(data['Fare'].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 16 columns):
# Age            1046 non-null float64
# Cabin          295 non-null object
# Embarked       1309 non-null object
# Fare           1309 non-null float64
# Name           1309 non-null object
# Parch          1309 non-null int64
# PassengerId    1309 non-null int64
# Pclass         1309 non-null int64
# Sex            1309 non-null object
# SibSp          1309 non-null int64
# Survived       891 non-null float64
# Ticket         1309 non-null object
# Family_Size    1309 non-null int64
# Title1         1309 non-null object
# Title2         1309 non-null object
# Ticket_info    1309 non-null object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 163.7+ KB

# %%
data['Cabin'].head(10)
# Out:
# 0     NaN
# 1     C85
# 2     NaN
# 3    C123
# 4     NaN
# 5     NaN
# 6     E46
# 7     NaN
# 8     NaN
# 9     NaN
# Name: Cabin, dtype: object

# %%
data['Cabin'] = data['Cabin'].apply(lambda x : str(x)[0] if not pd.isnull(x) else 'NoCabin')

# %%
data['Cabin'].unique()
# Out:
# array(['N', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
sns.countplot(data['Cabin'], hue=data['Survived'])

# %%
data['Sex'] = data['Sex'].astype('category').cat.codes
data['Embarked'] = data['Embarked'].astype('category').cat.codes
data['Pclass'] = data['Pclass'].astype('category').cat.codes
data['Title1'] = data['Title1'].astype('category').cat.codes
data['Title2'] = data['Title2'].astype('category').cat.codes
data['Cabin'] = data['Cabin'].astype('category').cat.codes
data['Ticket_info'] = data['Ticket_info'].astype('category').cat.codes

# %%
dataAgeNull = data[data["Age"].isnull()]
dataAgeNotNull = data[data["Age"].notnull()]
remove_outlier = dataAgeNotNull[(np.abs(dataAgeNotNull["Fare"]-dataAgeNotNull["Fare"].mean())>(4*dataAgeNotNull["Fare"].std()))|
                      (np.abs(dataAgeNotNull["Family_Size"]-dataAgeNotNull["Family_Size"].mean())>(4*dataAgeNotNull["Family_Size"].std()))                     
                     ]
rfModel_age = RandomForestRegressor(n_estimators=2000,random_state=42)
ageColumns = ['Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title1', 'Title2','Cabin','Ticket_info']
rfModel_age.fit(remove_outlier[ageColumns], remove_outlier["Age"])

ageNullValues = rfModel_age.predict(X= dataAgeNull[ageColumns])
dataAgeNull.loc[:,"Age"] = ageNullValues
data = dataAgeNull.append(dataAgeNotNull)
data.reset_index(inplace=True, drop=True)
# Out:
# /home/rozen/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dataTrain = data[pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])
dataTest = data[~pd.notnull(data['Survived'])].sort_values(by=["PassengerId"])

# %%
dataTrain.columns
# Out:
# Index(['Age', 'Cabin', 'Embarked', 'Fare', 'Name', 'Parch', 'PassengerId',
#        'Pclass', 'Sex', 'SibSp', 'Survived', 'Ticket', 'Family_Size', 'Title1',
#        'Title2', 'Ticket_info', 'Cabin2'],
#       dtype='object')

# %%
dataTrain = dataTrain[['Survived', 'Age', 'Embarked', 'Fare',  'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]
dataTest = dataTest[['Age', 'Embarked', 'Fare', 'Pclass', 'Sex', 'Family_Size', 'Title2','Ticket_info','Cabin']]

# %%
dataTrain
# Out:
#      Survived        Age  Embarked      Fare  Pclass  Sex  Family_Size  \
# 263       0.0  22.000000         2    7.2500       2    1            1
# 264       1.0  38.000000         0   71.2833       0    0            1
# 265       1.0  26.000000         2    7.9250       2    0            0
# 266       1.0  35.000000         2   53.1000       0    0            1
# 267       0.0  35.000000         2    8.0500       2    1            0
# 0         0.0  41.326267         1    8.4583       2    1            0
# 268       0.0  54.000000         2   51.8625       0    1            0
# 269       0.0   2.000000         2   21.0750       2    1            4
# 270       1.0  27.000000         2   11.1333       2    0            2
# 271       1.0  14.000000         0   30.0708       1    0            1
# 272       1.0   4.000000         2   16.7000       2    0            2
# 273       1.0  58.000000         2   26.5500       0    0            0
# 274       0.0  20.000000         2    8.0500       2    1            0
# 275       0.0  39.000000         2   31.2750       2    1            6
# 276       0.0  14.000000         2    7.8542       2    0            0
# 277       1.0  55.000000         2   16.0000       1    0            0
# 278       0.0   2.000000         1   29.1250       2    1            5
# 1         1.0  41.616486         2   13.0000       1    1            0
# 279       0.0  31.000000         2   18.0000       2    0            1
# 2         1.0  46.792625         0    7.2250       2    0            0
# 280       0.0  35.000000         2   26.0000       1    1            0
# 281       1.0  34.000000         2   13.0000       1    1            0
# 282       1.0  15.000000         1    8.0292       2    0            0
# 283       1.0  28.000000         2   35.5000       0    1            0
# 284       0.0   8.000000         2   21.0750       2    0            4
# 285       1.0  38.000000         2   31.3875       2    0            6
# 3         0.0  41.326267         0    7.2250       2    1            0
# 286       0.0  19.000000         2  263.0000       0    1            5
# 4         1.0  34.860886         1    7.8792       2    0            0
# 5         0.0  39.428653         2    7.8958       2    1            0
# ..        ...        ...       ...       ...     ...  ...          ...
# 951       0.0  21.000000         2   11.5000       1    1            1
# 952       1.0  48.000000         2   25.9292       0    0            0
# 173       0.0  15.470411         2   69.5500       2    0           10
# 953       0.0  24.000000         2   13.0000       1    1            0
# 954       1.0  42.000000         2   13.0000       1    0            0
# 955       1.0  27.000000         0   13.8583       1    0            1
# 956       0.0  31.000000         2   50.4958       0    1            0
# 174       0.0  39.428653         2    9.5000       2    1            0
# 957       1.0   4.000000         2   11.1333       2    1            2
# 958       0.0  26.000000         2    7.8958       2    1            0
# 959       1.0  47.000000         2   52.5542       0    0            2
# 960       0.0  33.000000         2    5.0000       0    1            0
# 961       0.0  47.000000         2    9.0000       2    1            0
# 962       1.0  28.000000         0   24.0000       1    0            1
# 963       1.0  15.000000         0    7.2250       2    0            0
# 964       0.0  20.000000         2    9.8458       2    1            0
# 965       0.0  19.000000         2    7.8958       2    1            0
# 175       0.0  39.428653         2    7.8958       2    1            0
# 966       1.0  56.000000         0   83.1583       0    0            1
# 967       1.0  25.000000         2   26.0000       1    0            1
# 968       0.0  33.000000         2    7.8958       2    1            0
# 969       0.0  22.000000         2   10.5167       2    0            0
# 970       0.0  28.000000         2   10.5000       1    1            0
# 971       0.0  25.000000         2    7.0500       2    1            0
# 972       0.0  39.000000         1   29.1250       2    0            5
# 973       0.0  27.000000         2   13.0000       1    1            0
# 974       1.0  19.000000         2   30.0000       0    0            0
# 176       0.0  19.099409         2   23.4500       2    0            3
# 975       1.0  26.000000         0   30.0000       0    1            0
# 976       0.0  32.000000         1    7.7500       2    1            0
#
#      Title2  Ticket_info  Cabin
# 263       3            2      7
# 264       4           14      2
# 265       2           31      7
# 266       4           36      2
# 267       3           36      7
# 0         3           36      7
# 268       3           36      4
# 269       1           36      7
# 270       4           36      7
# 271       4           36      7
# 272       2           15      6
# 273       2           36      2
# 274       3            2      7
# 275       3           36      7
# 276       2           36      7
# 277       4           36      7
# 278       1           36      7
# 1         3           36      7
# 279       4           36      7
# 2         4           36      7
# 280       3           36      7
# 281       3           36      3
# 282       2           36      7
# 283       3           36      0
# 284       2           36      7
# 285       4           36      7
# 3         3           36      7
# 286       3           36      2
# 4         2           36      7
# 5         3           36      7
# ..      ...          ...    ...
# 951       3           36      7
# 952       4           36      3
# 173       2            7      7
# 953       3           36      7
# 954       4           36      7
# 955       2           22      7
# 956       3           14      0
# 174       3           36      7
# 957       1           36      7
# 958       3           36      7
# 959       4           36      3
# 960       3           36      1
# 961       3           36      7
# 962       4           16      7
# 963       2           36      7
# 964       3           36      7
# 965       3           36      7
# 175       3           36      7
# 966       4           36      2
# 967       4           36      7
# 968       3           36      7
# 969       2           36      7
# 970       3            8      7
# 971       3           28      7
# 972       4           36      7
# 973       3           36      7
# 974       2           36      1
# 176       2           34      7
# 975       3           36      2
# 976       3           36      7
#
# [891 rows x 10 columns]

# %% [markdown]
# ## Model training

# %%
from sklearn.ensemble import RandomForestClassifier
 
rf = RandomForestClassifier(criterion='gini', 
                             n_estimators=1000,
                             min_samples_split=12,
                             min_samples_leaf=1,
                             oob_score=True,
                             random_state=1,
                             n_jobs=-1) 

rf.fit(dataTrain.iloc[:, 1:], dataTrain.iloc[:, 0])
print("%.4f" % rf.oob_score_)
# Out:
# 0.8260

# %%
pd.concat((pd.DataFrame(dataTrain.iloc[:, 1:].columns, columns = ['variable']), 
           pd.DataFrame(rf.feature_importances_, columns = ['importance'])), 
          axis = 1).sort_values(by='importance', ascending = False)[:20]
# Out:
#       variable  importance
# 4          Sex    0.265254
# 2         Fare    0.162216
# 6       Title2    0.155521
# 0          Age    0.133391
# 3       Pclass    0.089140
# 5  Family_Size    0.070437
# 8        Cabin    0.065385
# 7  Ticket_info    0.032729
# 1     Embarked    0.025927

# %%
rf_res =  rf.predict(dataTest)
submit['Survived'] = rf_res
submit['Survived'] = submit['Survived'].astype(int)
submit.to_csv('submit.csv', index= False)

# %%
submit
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         0
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         0
# 19           911         1
# 20           912         0
# 21           913         1
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         1
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         0
# 391         1283         1
# 392         1284         1
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         0
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         0
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
